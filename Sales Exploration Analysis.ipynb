# %%
import pandas as pd
import numpy as np
from matplotlib.pylab import plt
import seaborn as sns
plt.style.use('ggplot')
pd.set_option('max_columns', 18)

# %%
df= pd.read_csv(r"C:\Users\CHISA\Downloads\Sales.csv")

# %%
df.shape
# Out:
# (113036, 18)

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
#df.describe()
# Out:
#                  Day           Year   Customer_Age  Order_Quantity  \
# count  113036.000000  113036.000000  113036.000000   113036.000000
# mean       15.665753    2014.401739      35.919212       11.901660
# std         8.781567       1.272510      11.021936        9.561857
# min         1.000000    2011.000000      17.000000        1.000000
# 25%         8.000000    2013.000000      28.000000        2.000000
# 50%        16.000000    2014.000000      35.000000       10.000000
# 75%        23.000000    2016.000000      43.000000       20.000000
# max        31.000000    2016.000000      87.000000       32.000000
#
#            Unit_Cost     Unit_Price         Profit           Cost  \
# count  113036.000000  113036.000000  113036.000000  113036.000000
# mean      267.296366     452.938427     285.051665     469.318695
# std       549.835483     922.071219     453.887443     884.866118
# min         1.000000       2.000000     -30.000000       1.000000
# ...

# %%
#df.isna().sum()
# Out:
# Date                0
# Day                 0
# Month               0
# Year                0
# Customer_Age        0
# Age_Group           0
# Customer_Gender     0
# Country             0
# State               0
# Product_Category    0
# Sub_Category        0
# Product             0
# Order_Quantity      0
# Unit_Cost           0
# Unit_Price          0
# Profit              0
# Cost                0
# Revenue             0
# dtype: int64

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 113031    False
# 113032    False
# 113033    False
# 113034    False
# 113035    False
# Length: 113036, dtype: bool

# %%
df.loc[df.duplicated(subset=['Product'])].head(10)
# Out:
#           Date  Day     Month  Year  Customer_Age             Age_Group  \
# 1   2015-11-26   26  November  2015            19           Youth (<25)
# 2   2014-03-23   23     March  2014            49        Adults (35-64)
# 3   2016-03-23   23     March  2016            49        Adults (35-64)
# 4   2014-05-15   15       May  2014            47        Adults (35-64)
# 5   2016-05-15   15       May  2016            47        Adults (35-64)
# 6   2014-05-22   22       May  2014            47        Adults (35-64)
# 7   2016-05-22   22       May  2016            47        Adults (35-64)
# 8   2014-02-22   22  February  2014            35        Adults (35-64)
# 9   2016-02-22   22  February  2016            35        Adults (35-64)
# 10  2013-07-30   30      July  2013            32  Young Adults (25-34)
#
#    Customer_Gender    Country             State Product_Category Sub_Category  \
# 1                M     Canada  British Columbia      Accessories   Bike Racks
# ...

# %%
#check example duplicate
df.query('Product== "Hitch Rack - 4-Bike"')
# Out:
#            Date  Day     Month  Year  Customer_Age             Age_Group  \
# 0    2013-11-26   26  November  2013            19           Youth (<25)
# 1    2015-11-26   26  November  2015            19           Youth (<25)
# 2    2014-03-23   23     March  2014            49        Adults (35-64)
# 3    2016-03-23   23     March  2016            49        Adults (35-64)
# 4    2014-05-15   15       May  2014            47        Adults (35-64)
# ..          ...  ...       ...   ...           ...                   ...
# 591  2015-10-27   27   October  2015            32  Young Adults (25-34)
# 592  2013-07-22   22      July  2013            18           Youth (<25)
# 593  2015-07-22   22      July  2015            18           Youth (<25)
# 594  2013-10-10   10   October  2013            18           Youth (<25)
# 595  2015-10-10   10   October  2015            18           Youth (<25)
#
#     Customer_Gender        Country             State Product_Category  \
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
#        'Customer_Gender', 'Country', 'State', 'Product_Category',
#        'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
#        'Profit', 'Cost', 'Revenue'],
#       dtype='object')

# %%
~df.duplicated(subset=['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
       'Customer_Gender', 'Country', 'State', 'Product_Category',
       'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
       'Profit', 'Cost', 'Revenue']).sum()
# Out:
# -1001

# %%
~df.duplicated(subset=['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
       'Customer_Gender', 'Country', 'State', 'Product_Category',
       'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
       'Profit', 'Cost', 'Revenue'])
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4         True
#           ...
# 113031    True
# 113032    True
# 113033    True
# 113034    True
# 113035    True
# Length: 113036, dtype: bool

# %%
df.loc[~df.duplicated(subset=['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
       'Customer_Gender', 'Country', 'State', 'Product_Category',
       'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
       'Profit', 'Cost', 'Revenue'])]

# %%
df.loc[~df.duplicated(subset=['Date', 'Day', 'Month', 'Year', 'Customer_Age', 'Age_Group',
       'Customer_Gender', 'Country', 'State', 'Product_Category',
       'Sub_Category', 'Product', 'Order_Quantity', 'Unit_Cost', 'Unit_Price',
       'Profit', 'Cost', 'Revenue'])] \
    .reset_index(drop=True)
# Out:
#               Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0       2013-11-26   26  November  2013            19     Youth (<25)
# 1       2015-11-26   26  November  2015            19     Youth (<25)
# 2       2014-03-23   23     March  2014            49  Adults (35-64)
# 3       2016-03-23   23     March  2016            49  Adults (35-64)
# 4       2014-05-15   15       May  2014            47  Adults (35-64)
# ...            ...  ...       ...   ...           ...             ...
# 112031  2016-04-12   12     April  2016            41  Adults (35-64)
# 112032  2014-04-02    2     April  2014            18     Youth (<25)
# 112033  2016-04-02    2     April  2016            18     Youth (<25)
# 112034  2014-03-04    4     March  2014            37  Adults (35-64)
# 112035  2016-03-04    4     March  2016            37  Adults (35-64)
#
#        Customer_Gender         Country             State Product_Category  \
# ...

# %%
df.head()
# Out:
#          Date  Day     Month  Year  Customer_Age       Age_Group  \
# 0  2013-11-26   26  November  2013            19     Youth (<25)
# 1  2015-11-26   26  November  2015            19     Youth (<25)
# 2  2014-03-23   23     March  2014            49  Adults (35-64)
# 3  2016-03-23   23     March  2016            49  Adults (35-64)
# 4  2014-05-15   15       May  2014            47  Adults (35-64)
#
#   Customer_Gender    Country             State Product_Category Sub_Category  \
# 0               M     Canada  British Columbia      Accessories   Bike Racks
# 1               M     Canada  British Columbia      Accessories   Bike Racks
# 2               M  Australia   New South Wales      Accessories   Bike Racks
# 3               M  Australia   New South Wales      Accessories   Bike Racks
# 4               F  Australia   New South Wales      Accessories   Bike Racks
#
#                Product  Order_Quantity  Unit_Cost  Unit_Price  Profit  Cost  \
# ...

# %%
df['Country'].value_counts()\
    .head(10)\
    .plot(kind='bar')

# %%
sns.catplot(x='Country', y='Customer_Age', data=df, kind='point')
plt.xticks(rotation=90)
# Out:
# (array([0, 1, 2, 3, 4, 5]), <a list of 6 Text xticklabel objects>)

# %%
#sns.set_theme(style='darkgrid')
#sns.lineplot(x='timestamp',  y='quote.USD.price', data=df11)
